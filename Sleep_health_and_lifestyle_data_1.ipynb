# %% [markdown]
# ![](https://img.freepik.com/free-vector/healthy-lifestyle-diet-fitness-vector-sign-shape-heart-with-multiple-icons-depicting-various-sports-vegetables-cereals-seafood-meat-fruit-sleep-weight-beverages_1284-44073.jpg?w=740&t=st=1688649436~exp=1688650036~hmac=75a614b6689928a1d497168e3c47dff3e726f240ad93e4afd20d0943c6d413d0)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
data=data.drop('Person ID',axis=1)

# %% [markdown]
# - `data`: This is the name of the DataFrame on which the operation is performed.
# - `.drop()`: This method is used to remove elements from a DataFrame.
# - `'Person ID'`: This is the label of the column you want to drop. In this case, the column with the label 'Person ID' will be removed.
# - `axis=1`: The `axis` parameter specifies whether we want to drop a row (axis=0) or a column (axis=1). By setting `axis=1`, we are indicating that we want to drop a column.
#
# After executing this code, the 'Person ID' column will be removed from the 'data' DataFrame, and the modified DataFrame will be assigned back to the variable 'data'. The resulting DataFrame will not contain the 'Person ID' column.

# %% [markdown]
# # Check the Shape

# %%
print(f'the dataset contains {data.shape[1]} columns and {data.shape[0]} rows')
# Out:
# the dataset contains 12 columns and 374 rows

# %%
# All columns informations 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    object
#  1   Age                      374 non-null    int64
#  2   Occupation               374 non-null    object
#  3   Sleep Duration           374 non-null    float64
#  4   Quality of Sleep         374 non-null    int64
#  5   Physical Activity Level  374 non-null    int64
#  6   Stress Level             374 non-null    int64
#  7   BMI Category             374 non-null    object
#  8   Blood Pressure           374 non-null    object
#  9   Heart Rate               374 non-null    int64
#  10  Daily Steps              374 non-null    int64
#  11  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 35.2+ KB

# %% [markdown]
# # Checking the null values

# %%
data.isnull().sum()/len(data.shape)*100
# Out:
# Gender                     0.0
# Age                        0.0
# Occupation                 0.0
# Sleep Duration             0.0
# Quality of Sleep           0.0
# Physical Activity Level    0.0
# Stress Level               0.0
# BMI Category               0.0
# Blood Pressure             0.0
# Heart Rate                 0.0
# Daily Steps                0.0
# Sleep Disorder             0.0
# dtype: float64

# %% [markdown]
# The expression `data.isnull().sum()` is used to calculate the number of null values (missing values) in each column of the DataFrame 'data'.
#
# The `.isnull()` method returns a DataFrame of the same shape as 'data', where each cell contains a boolean value indicating whether it is null (`True`) or not null (`False`). Calling `.sum()` on this DataFrame sums the boolean values along each column, resulting in a Series that shows the count of null values for each column.
#
# On the other hand, `len(data.shape)` returns the total number of dimensions of the DataFrame 'data'. Since the shape attribute of a DataFrame returns a tuple of (rows, columns), `len(data.shape)` gives the total number of columns in the DataFrame.
#
# The expression `(data.isnull().sum() / len(data.shape)) * 100` calculates the percentage of null values for each column by dividing the count of null values by the total number of columns and then multiplying it by 100.

# %%
data.describe().style.background_gradient(cmap='nipy_spectral')
# Out:
# <style type="text/css">
# #T_8a4ab_row0_col0, #T_8a4ab_row0_col1, #T_8a4ab_row0_col2, #T_8a4ab_row0_col3, #T_8a4ab_row0_col4, #T_8a4ab_row0_col5, #T_8a4ab_row7_col6 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_8a4ab_row0_col6, #T_8a4ab_row2_col0, #T_8a4ab_row2_col1, #T_8a4ab_row2_col2, #T_8a4ab_row2_col3, #T_8a4ab_row2_col4, #T_8a4ab_row2_col5, #T_8a4ab_row3_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col0 {
#   background-color: #850096;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col1, #T_8a4ab_row1_col2, #T_8a4ab_row5_col1, #T_8a4ab_row6_col1, #T_8a4ab_row6_col2, #T_8a4ab_row7_col4 {
#   background-color: #25002b;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col3 {
#   background-color: #78009b;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col4, #T_8a4ab_row5_col4 {
#   background-color: #130015;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col5, #T_8a4ab_row5_col5 {
#   background-color: #0000c5;
#   color: #f1f1f1;
# }
# #T_8a4ab_row1_col6 {
# ...

# %% [markdown]
# The `data.describe()` method provides descriptive statistics for numerical columns in the DataFrame 'data'. It calculates various statistical measures, including count, mean, standard deviation, minimum value, quartiles, and maximum value, for each numerical column.
#
# The output provides the following information for each numerical column:
#
# - `count`: The number of non-null values in the column.
# - `mean`: The average (mean) value of the column.
# - `std`: The standard deviation, which measures the dispersion or variability of the values in the column.
# - `min`: The minimum value in the column.
# - `25%`: The first quartile, also known as the 25th percentile. It represents the value below which 25% of the data falls.
# - `50%`: The second quartile, also known as the median or 50th percentile. It represents the value below which 50% of the data falls.
# - `75%`: The third quartile, also known as the 75th percentile. It represents the value below which 75% of the data falls.
# - `max`: The maximum value in the column.

# %% [markdown]
# # Visualizing correlation map

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),cmap='viridis',annot=True,fmt='.2f',linewidths=1)
plt.title("Title of the Heatmap")
plt.show()

# %% [markdown]
# - `plt.figure(figsize=(8,6))`: This line creates a figure with a specified size of 8 inches (width) by 6 inches (height). It sets the dimensions of the heatmap plot.
#
# - `sns.heatmap(data.corr(), cmap='viridis', annot=True, fmt='.2f', linewidths=1)`: This line generates the heatmap plot using Seaborn's `heatmap` function. It takes the correlation matrix of 'data' (`data.corr()`) as the input.
#
#   - `cmap='viridis'`: This sets the colormap for the heatmap to 'viridis', which provides a perceptually uniform range of colors from low to high values.
#
#   - `annot=True`: This parameter enables the annotation of each cell in the heatmap with its corresponding value.
#
#   - `fmt='.2f'`: This specifies the format of the annotation values as floating-point numbers with two decimal places.
#
#   - `linewidths=1`: This sets the width of the lines separating each cell in the heatmap to 1 pixel.

# %% [markdown]
#  # Explore Data Analysis

# %% [markdown]
# # Question asked for data
#    - Sleep disorder Percentage.
#    - Gender Percentage in the data using a pie chart.
#    - Distribution of age using a histogram .
#    - Determine the highest occupation in the dataset.
#    - Analyze the distribution od sleep duration based on gender.
#    - Visualize the avarage sleep duration acrooss different occupation using a bar chart .
#    - Explore the relation between avarage sleep duration with BMI category .
#    - Identify the domainant occupation with the male category .
#    - Find the avarage heart rate with BMI category .

# %% [markdown]
# # Find the Sleep disorder Percentage.

# %%
data['Sleep Disorder'].value_counts(normalize=True).sort_values(ascending=False)\
.plot(kind='pie', title='sleep Disorder percentage in the data',explode=[0.05,0.06,0.07],
labels=['None','sleep','Insomnia'],
colors=['#00FFBF','#819FF7','#E2A9F3'],
autopct='%1.2f%%',shadow=True)
# Out:
# <AxesSubplot:title={'center':'sleep Disorder percentage in the data'}, ylabel='Sleep Disorder'>

# %% [markdown]
# - `data['Sleep Disorder'].value_counts(normalize=True)`: This line calculates the value counts of each unique value in the 'Sleep Disorder' column and normalizes the counts to obtain percentages.
#
# - `.sort_values(ascending=False)`: This sorts the values in descending order based on the percentages.
#
# - `.plot(kind='pie', title='Sleep Disorder Percentage in the Data', explode=[0.05, 0.06, 0.07], labels=['None', 'Sleep', 'Insomnia'], colors=['#00FFBF', '#819FF7', '#E2A9F3'], autopct='%1.2f%%')`: This line creates a pie chart using the `plot` method. It specifies the chart type as 'pie' and provides additional parameters for customization.
#
#   - `kind='pie'`: This specifies the chart type as a pie chart.
#
#   - `title='Sleep Disorder Percentage in the Data'`: This sets the title of the pie chart.
#
#   - `explode=[0.05, 0.06, 0.07]`: This parameter controls the "explode" effect, where slices of the pie are offset from the center. Here, the first, second, and third slices are exploded by 5%, 6%, and 7% of the radius, respectively.
#
#   - `labels=['None', 'Sleep', 'Insomnia']`: This provides the labels for each slice of the pie chart.
#
#   - `colors=['#00FFBF', '#819FF7', '#E2A9F3']`: This sets the colors for each slice of the pie chart.
#
#   - `autopct='%1.2f%%'`: This formats the autopct (automatic percentage) labels to display the percentage values with two decimal places.

# %% [markdown]
# # Find the gender Percentage using data

# %%
data['Gender'].value_counts(normalize=True).sort_values(ascending=False)\
.plot(kind='pie', title='Gender Percentage in the Data', explode=[0.05, 0.02], 
      labels=['Male', 'Female'], colors=['#64FE2E', '#F5DA81'], autopct='%1.2f%%',shadow=True)
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
# - from the above two pie chart we can observe several pieces of information
#     - Firstly the highest parcentage in the sleep disorder `None` indicating that
#       a significant portion of the data does not have reported sleep disorder.
#       The second-Highest sleep disorder category is `sleep `
#     - In the second pie chart depicting gender percentages ,
#       the `male` percentage is higher as compare to the `female` percentage

# %%
#Distribution of age columns 
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Age', stat='count', bins=20, kde=True, color='b')
plt.title('Distribution of the Age')
plt.show()

# %% [markdown]
# - `sns.histplot`: This is the function provided by Seaborn to create a histogram plot.
#
# - `data=data`: This parameter specifies the DataFrame from which the data will be plotted.
#
# - `x='Age'`: This parameter specifies the column in the DataFrame to be plotted on the x-axis, which is 'Age' in this case.
#
# - `stat='count'`: This parameter specifies the statistical aggregation to be performed. Setting it to 'count' means that the height of each bin in the histogram represents the count of values falling within that bin.
#
# - `bins=20`: This parameter determines the number of bins or intervals to use in the histogram. Here, it is set to 20, meaning the data will be divided into 20 equal-width bins.
#
# - `kde=True`: This parameter controls whether to display a kernel density estimate (KDE) plot along with the histogram. When set to True, the KDE plot shows an estimation of the underlying distribution of the data.
#
# - `color='b'`: This parameter sets the color of the histogram bars. Here, it is set to 'b', which represents the color blue.
#
# # Observation
#  - In the age histogram there a noticeble representation of the age 43,Indicate that a
#    significant number of individual in    the dataset fall within this age range

# %% [markdown]
# # 4. Count Of The Occupation In The Data Using Bar Plot

# %%
data['Occupation'].value_counts(normalize=True).sort_values(ascending=False)\
.plot(kind='bar',title='Count of the occupation ',figsize=(8,6),
      color=['#0b0b61','#00FFBF','#64FE2E', '#F5DA81','#819FF7','#E2A9F3'])
plt.xlabel=('Occupation')
plt.ylabel('Count Of values ')
plt.show()

# %% [markdown]
# # Observation
#
# - From the above chart ,we can observe that :-
#
#   - In bar chart ,We can determine that most demanding job based on the dataset in `Nurse`
#   - while the least demanding job is `Manager`

# %% [markdown]
# # 5. Visualize the Sleep duration with the age wise

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data,x='Sleep Duration', bins=30,kde=True,hue='Gender')
plt.xlabel=('Sleep Duration')
plt.xlabel=('count')
plt.show()

# %% [markdown]
# # Observation
#
# - From the above chart ,we can observe that :-
#
#     - According to the histogram chart ,the avarage sleep duration for male approximately 7.7 hours
#       while for females it is around 8.5 hours .

# %% [markdown]
# # Find the Avarage Sleep time of the different Occupation

# %%
data.groupby('Occupation')['Quality of Sleep'].mean().sort_values(ascending=False)\
.plot(kind='bar',title='Avarage Sleep time of different Occupation ',figsize=(8,6),color=['#00FFBF','#64FE2E', '#F5DA81'])
plt.xlabel = ["Occupation"]
plt.ylabel=("Average sleep time")
plt.show()

# %% [markdown]
# # Observation
#
# - From the above chart ,we can observe that :-
#
#      - In the bar chart ,it is evident that the occupation `Engineer` has the highest sleep quality.
#        among the different roles,while the Occcupation `Sales Represntative ` has the lowest sleep quality

# %% [markdown]
# # Some intersting question asked in the data

# %% [markdown]
# ## Gender imbalance

# %%
imbalaced_data=data['Gender'].value_counts()[0]/data['Gender'].value_counts()[1]
print('\n Gender Imbalance ',imbalaced_data)
# Out:
#  Gender Imbalance  1.0216216216216216

# %%
#Find the which is the dominate_occupation in the data
dominate_occupation =data['Occupation'].value_counts().idxmax()
print('\n Dominate Occupation --->',dominate_occupation)
# Out:
#  Dominate Occupation ---> Nurse

# %%
#find the least demananding job 
least_demanding_job=data['Occupation'].value_counts().idxmin()
print('least Demanding Job from the Occupation --->',least_demanding_job)
# Out:
# least Demanding Job from the Occupation ---> Manager

# %%
# find the top 5 stress levels
top_5_stress_level=data['Stress Level'].value_counts().nlargest(5)
print('Common stress pattern--->',top_5_stress_level)
# Out:
# Common stress pattern---> 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# Name: Stress Level, dtype: int64

# %%
# find the age range in the data 
age_range=(data['Age'].min(),data['Age'].max())
print('\n Age Range= ',age_range)
# Out:
#  Age Range=  (27, 59)

# %%
# finid the daily step in the data 
daily_step=(data['Daily Steps'].min(),data['Daily Steps'].max()  )
print('Range of the  daily stpes =',daily_step)
# Out:
# Range of the  daily stpes = (3000, 10000)

# %%
# find the skewe of the sleep duration 
sleep_quality_skeweness=(data['Sleep Duration'].value_counts().skew())
print('Sleep Quality Skewness = ',sleep_quality_skeweness)
# Out:
# Sleep Quality Skewness =  0.7855254005718885

# %%
# Visualization of the physical activity with heart rate on gender 
plt.figure(figsize=(6,6))
sns.scatterplot(data=data,x='Physical Activity Level',y='Heart Rate',hue='Gender')
plt.title="Visualize the Physical activity with heart Rate"
plt.show()

# %% [markdown]
# # find the Relationship between `Heart Rate` with daily Steps on `Gender`

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=data,x='Heart Rate',y='Daily Steps',hue='Gender')
plt.title="Relationship with Heart Rate and Daily steps On Gender"
plt.show()

# %%
#Find the avarage Stress level the BMI category wise
plt.figure(figsize=(8,6))
data.groupby('BMI Category')['Stress Level'].mean().sort_values(ascending=False)\
.plot(kind='bar',title='Avarage Stress level for the BMI Category ',color=['#00FFBF','#64FE2E', '#F5DA81','#00FF34','#64FF2E'])
plt.xlabel = 'BMI Category'
plt.ylabel = "Average Stress level"

plt.show()

# %%
# find the avarage daily step with BMI category on gender using pivot table 
pd.pivot_table (data=data ,index='Gender',values='Daily Steps',columns='BMI Category',aggfunc='mean')
# Out:
# BMI Category       Normal  Normal Weight        Obese   Overweight
# Gender
# Female        6000.000000    6578.571429  3300.000000  7416.037736
# Male          7320.610687    7142.857143  3355.555556  5828.571429

# %%
# find the most demanding  occcupation with male  category
data.loc[data['Gender']=="Male"]['Occupation'].value_counts(normalize=True)\
.plot(kind='bar',title="Visualization the male Occupation",color=['red','orange','pink','skyblue','brown'])
plt.xlabel=('Occupation')
plt.ylabel = ('Count of values')
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
#    1. From the above chart ,we can observe an interesting pattern where overweight people to have higher stress level ,
#       while normal weight individual have lower stress level
#
#
#    2. Regarding the domaince of job roles in the male gender,it can be seen that the doctor profession is the most dominating
#       job,while the `accountant` role is relatively less domanant

# %%
# Create a histogram for distributing the avarage daily step 
plt.figure(figsize=(8,5))
sns.histplot(data['Daily Steps'],bins='auto',color=['red'],kde=True,)
plt.title=("Distribution of the daily steps")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Occupation', y='Quality of Sleep', hue='Gender',)
plt.xlabel=('Occupation')
plt.ylabel=('Quality of Sleep')
plt.title=("Quality of Sleep")
plt.xticks(rotation=60)
plt.show()

# %%
# visualization  the boxplot with the heart rate
plt.figure(figsize=(9,6))
sns.boxplot(data=data,x='Heart Rate',y='Age',hue='Gender')
plt.xlabel=("heart Rate")
plt.ylabel=("Age")
plt.show()

# %%
plt.figure(figsize=(8,6))
data['Blood Pressure'].value_counts(normalize=True).sort_values(ascending=False)\
.plot(kind='bar',title ='Visualiztionthe blood pressue',color=['Red','Orange','Purple','Pink'],)
plt.xlabel=("Blood Pressure")
plt.ylabel=("Count of value")
plt.show()

# %% [markdown]
# # Machine Learning  Modeling

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,ShuffleSplit
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
from xgboost import XGBClassifier
from catboost import CatBoostClassifier 
from sklearn.neighbors import KNeighborsClassifier

# %%
# convert the categorical data into numberical values
for col in data.select_dtypes(include='object'):
    label_encoder=LabelEncoder()
    label_encoder.fit(data[col].unique())
    data[col]=label_encoder.transform(data[col])

# %%
# divide into the data into independend and dependend variable 
X=data.drop(['Sleep Disorder'],axis=1)
y=data['Sleep Disorder']

# scaling the valuess 
scaler=MinMaxScaler()
scaler.fit(X)
X=scaler.fit_transform(X)

# %%
# split the data into train test split 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=200)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (261, 11)
# (113, 11)
# (261,)
# (113,)

# %%
algo={
    'logistic_regression':{
        'model': LogisticRegression(),
        'params':{
            
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            
        }
    },
    'decision_tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy','log_loss'],
            'splitter':['best','random']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10,20,50],
            'criterion':['gini','entropy','log_loss']
        }
    },
    'ada_boost_classifier':{
        'model': AdaBoostClassifier(),
        'params':{
            'n_estimators':[1,5,10,20,50,100],
        }
    },
    'gradient_Boosting_classifier':{
        'model':GradientBoostingClassifier(),
        'params':{
            'n_estimators':[1,5,10,20,50,100],
        }
    },
    'xbgclassifier':{
        'model':XGBClassifier(),
        'params':{
            'n_estimators':[1,5,10,20,50],
        }
    },
    'cat_boost_classifier':{
        'model':CatBoostClassifier(),
        'params':{
            'iterations':[1],
        }
    },
    'knn_classifier':{
        'model':KNeighborsClassifier(),
        'params':{
            
        }
    }
}

# %%
score=[]
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=10)
for algo_name,mp in algo.items():
    grid=GridSearchCV(mp['model'],mp['params'],cv=cv,return_train_score=False)
    grid.fit(X,y)
    score.append({
        'model':algo_name,
        'best_score':grid.best_score_,
        'best_params':grid.best_params_
    })
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6587861	total: 3.68ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6686615	total: 2.83ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6705082	total: 2.66ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6458583	total: 2.6ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6547457	total: 2.17ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6587434	total: 2.63ms	remaining: 0us

# %%
score=pd.DataFrame(score,columns=['model','best_score','best_params'])
score.head()
# Out:
#                   model  best_score  \
# 0   logistic_regression    0.877333
# 1                   SVM    0.882667
# 2         decision_tree    0.874667
# 3         random_forest    0.893333
# 4  ada_boost_classifier    0.858667
#
#                                     best_params
# 0                                            {}
# 1                                            {}
# 2   {'criterion': 'gini', 'splitter': 'random'}
# 3  {'criterion': 'entropy', 'n_estimators': 50}
# 4                           {'n_estimators': 5}

# %%
# Imbalaced the data set and create a function for the machine learing model 
from imblearn.combine import SMOTETomek
sm=SMOTETomek()
X_train_sm,y_train_sm=sm.fit_resample(X_train,y_train)
def model_building(model,X_train,X_test,y_train,y_test):
    model.fit(X_train_sm,y_train_sm)
    y_pred=model.predict(X_test)
    print(f' The accuracy score of the {model} is {accuracy_score(y_test,y_pred)*100:.2f}')
    print(classification_report(y_test,y_pred))
    confusion=confusion_matrix(y_test,y_pred)
    print(sns.heatmap(confusion,annot=True,cmap='gist_earth'))

# %%
# Applying the catboostClassifier
logistic=CatBoostClassifier(iterations=1)
model_building(logistic,X_train,X_test,y_train,y_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6615544	total: 5.2ms	remaining: 0us
#  The accuracy score of the <catboost.core.CatBoostClassifier object at 0x0000023E9C3A21F0> is 84.96
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79        20
#            1       0.86      0.91      0.89        69
#            2       0.82      0.75      0.78        24
#
#     accuracy                           0.85       113
#    macro avg       0.84      0.80      0.82       113
# weighted avg       0.85      0.85      0.85       113
#
# AxesSubplot(0.125,0.11;0.62x0.77)

# %%
# applying the catboostclassifier
xbg=XGBClassifier()
model_building(xbg,X_train,X_test,y_train,y_test)
# Out:
#  The accuracy score of the XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) is 90.27
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        20
#            1       0.97      0.93      0.95        69
# ...

# %%
# applying the catboostclassifier
KNN=KNeighborsClassifier()
model_building(KNN,X_test,X_test,y_train,y_test)
# Out:
#  The accuracy score of the KNeighborsClassifier() is 88.50
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        20
#            1       0.97      0.88      0.92        69
#            2       0.79      0.92      0.85        24
#
#     accuracy                           0.88       113
#    macro avg       0.84      0.88      0.86       113
# weighted avg       0.89      0.88      0.89       113
#
# AxesSubplot(0.125,0.11;0.62x0.77)

# %%
grad=GradientBoostingClassifier()
model_building(grad,X_train,X_test,y_train,y_test)
# Out:
#  The accuracy score of the GradientBoostingClassifier() is 92.04
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        20
#            1       0.97      0.94      0.96        69
#            2       0.81      0.92      0.86        24
#
#     accuracy                           0.92       113
#    macro avg       0.89      0.90      0.90       113
# weighted avg       0.92      0.92      0.92       113
#
# AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
# # Conclusion :

# %% [markdown]
# - Visualization such as bia chart, pia chart and other types of chart are created  to present to finding .
# - Machaine Learning algorithm , specifically gradientBoostingClassifier and XGBClassifier are apply to the data , and they      achive high accuracy score.

# %% [markdown]
# # Thank you
